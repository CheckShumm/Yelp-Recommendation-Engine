# %%
# importing libraries

import numpy as np
import pandas as pd

# plotting
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import style
style.use('ggplot')

# %%
# load data
restDF = pd.read_csv("../data/yelp_business.csv")
restDF.head()
# Out:
#               business_id                        name neighborhood  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"          NaN
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"          NaN
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"          NaN
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"          NaN
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"          NaN
#
#                             address            city state postal_code  \
# 0        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ       85044
# 1              "3101 Washington Rd"        McMurray    PA       15317
# 2          "6025 N 27th Ave, Ste 1"         Phoenix    AZ       85017
# 3  "5000 Arizona Mills Cr, Ste 435"           Tempe    AZ       85282
# 4                    "581 Howe Ave"  Cuyahoga Falls    OH       44221
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  33.330690 -111.978599    4.0            22        1
# 1  40.291685  -80.104900    3.0            11        1
# 2  33.524903 -112.115310    1.5            18        1
# 3  33.383147 -111.964725    3.0             9        0
# 4  41.119535  -81.475690    3.5           116        1
#
#                                           categories
# 0  Dentists;General Dentistry;Health & Medical;Or...
# 1  Hair Stylists;Hair Salons;Men's Hair Salons;Bl...
# 2  Departments of Motor Vehicles;Public Services ...
# 3                            Sporting Goods;Shopping
# 4  American (New);Nightlife;Bars;Sandwiches;Ameri...

# %%
# Function to calculate distance from a restaurant
def getDistance(lat, lon):
    # approximate radius of earth in km
    R = 6373.0
    myLat = 45.393220
    myLon = -73.493000

    dlon = myLon - lon
    dlat = myLat - lat

    a = np.sin(dlat / 2)**2 + np.cos(lat) * np.cos(myLat) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))

    distance = R * c
    
    return distance

# %%
# Filter business data to keep only restaurant businesses
restDF = restDF[restDF.categories.str.contains("Restaurants")]
restDF.head()
# Out:
#                business_id                          name        neighborhood  \
# 4   PfOCPjBrlQAnz__NXj9h_w    "Brick House Tavern + Tap"                 NaN
# 5   o9eMRCWt5PkpLDE0gOPtcQ                     "Messina"                 NaN
# 10  XOSRcvtaKc_Q5H1SAzN20A           "East Coast Coffee"                 NaN
# 14  fNMVV_ZX7CJSDWQGdOM8Nw  "Showmars Government Center"              Uptown
# 15  l09JfMeQ6ynYs5MCJtrcmQ              "Alize Catering"  Yonge and Eglinton
#
#                address            city state postal_code   latitude  \
# 4       "581 Howe Ave"  Cuyahoga Falls    OH       44221  41.119535
# 5     "Richterstr. 11"       Stuttgart    BW       70567  48.727200
# 10  "737 West Pike St"         Houston    PA       15342  40.241548
# 14      "600 E 4th St"       Charlotte    NC       28202  35.221647
# 15     "2459 Yonge St"         Toronto    ON     M4P 2H6  43.711399
#
#     longitude  stars  review_count  is_open  \
# 4  -81.475690    3.5           116        1
# 5    9.147950    4.0             5        1
# 10 -80.212815    4.5             3        0
# 14 -80.839345    3.5             7        1
# 15 -79.399339    3.0            12        0
#
#                                            categories
# 4   American (New);Nightlife;Bars;Sandwiches;Ameri...
# 5                                 Italian;Restaurants
# 10  Breakfast & Brunch;Gluten-Free;Coffee & Tea;Fo...
# 14                 Restaurants;American (Traditional)
# 15                         Italian;French;Restaurants

# %%
# restaurant data frame count
print(restDF['business_id'].count())
# Out:
# 54618

# %%
# store data to csv file
restDF.to_csv('../data/yelp_restaurant.csv', encoding='utf-8', index=False)

# %%
# load review data
revDF = pd.read_csv("../data/yelp_review.csv")
print("row count: ", revDF['business_id'].count())
# Out:
# row count:  5261668

# %%
# A look at the review dataset 
revDF.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  vkVSCC7xljjrAI4UGfnKEQ  bv2nCi5Qv5vroFiqKGopiw  AEx2SYEUJmTxVVB18LlCwA
# 1  n6QzIUObkYshz4dz2QRJTw  bv2nCi5Qv5vroFiqKGopiw  VR6GpWIda3SfvPC-lg9H3w
# 2  MV3CcKScW05u5LVfF6ok0g  bv2nCi5Qv5vroFiqKGopiw  CKC0-MOWMqoeWf6s-szl8g
# 3  IXvOzsEMYtiJI0CARmj77Q  bv2nCi5Qv5vroFiqKGopiw  ACFtxLv8pGrrxMm6EgjreA
# 4  L_9BTb55X0GDtThi6GlZ6w  bv2nCi5Qv5vroFiqKGopiw  s2I_Ni76bjJNK9yG60iD-Q
#
#    stars        date                                               text  \
# 0      5  2016-05-28  Super simple place but amazing nonetheless. It...
# 1      5  2016-05-28  Small unassuming place that changes their menu...
# 2      5  2016-05-28  Lester's is located in a beautiful neighborhoo...
# 3      4  2016-05-28  Love coming here. Yes the place always needs t...
# 4      4  2016-05-28  Had their chocolate almond croissant and it wa...
#
#    useful  funny  cool
# 0       0      0     0
# 1       0      0     0
# 2       0      0     0
# 3       0      0     0
# 4       0      0     0

# %%
# Removing un-necessary column data
revDF.drop('date', axis=1, inplace=True)
revDF.drop('text', axis=1, inplace=True)
revDF.drop('useful', axis=1, inplace=True)
revDF.drop('funny', axis=1, inplace=True)
revDF.drop('cool', axis=1, inplace=True)
revDF.drop('review_id', axis=1, inplace=True)
revDF.head()
# Out:
#                   user_id             business_id  stars
# 0  bv2nCi5Qv5vroFiqKGopiw  AEx2SYEUJmTxVVB18LlCwA      5
# 1  bv2nCi5Qv5vroFiqKGopiw  VR6GpWIda3SfvPC-lg9H3w      5
# 2  bv2nCi5Qv5vroFiqKGopiw  CKC0-MOWMqoeWf6s-szl8g      5
# 3  bv2nCi5Qv5vroFiqKGopiw  ACFtxLv8pGrrxMm6EgjreA      4
# 4  bv2nCi5Qv5vroFiqKGopiw  s2I_Ni76bjJNK9yG60iD-Q      4

# %%
# Filter review data to keep only restaurant businesses
restRevDF = revDF[revDF.business_id.isin(restDF.business_id)]
restRevDF.head()
print('reduced row count: ', restRevDF['business_id'].count())
# Out:
# reduced row count:  3221418

# %%
# A look at the filtered review dataset
restRevDF.head()
# Out:
#                   user_id             business_id  stars
# 0  bv2nCi5Qv5vroFiqKGopiw  AEx2SYEUJmTxVVB18LlCwA      5
# 1  bv2nCi5Qv5vroFiqKGopiw  VR6GpWIda3SfvPC-lg9H3w      5
# 2  bv2nCi5Qv5vroFiqKGopiw  CKC0-MOWMqoeWf6s-szl8g      5
# 3  bv2nCi5Qv5vroFiqKGopiw  ACFtxLv8pGrrxMm6EgjreA      4
# 4  bv2nCi5Qv5vroFiqKGopiw  s2I_Ni76bjJNK9yG60iD-Q      4

# %%
# Convert business_id to a numerical value from stringType
restRevDF['restaurantID'] = restRevDF.groupby(['business_id']).ngroup()
# Out:
# c:\users\nathan shumm\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Convert user_id to a numerical value from stringType
restRevDF['userID'] = restRevDF.groupby(['user_id']).ngroup()
# Out:
# c:\users\nathan shumm\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# A look at the new data
restRevDF.head(100)
# Out:
#                     user_id             business_id  stars  restaurantID  \
# 0    bv2nCi5Qv5vroFiqKGopiw  AEx2SYEUJmTxVVB18LlCwA      5          9594
# 1    bv2nCi5Qv5vroFiqKGopiw  VR6GpWIda3SfvPC-lg9H3w      5         27706
# 2    bv2nCi5Qv5vroFiqKGopiw  CKC0-MOWMqoeWf6s-szl8g      5         11350
# 3    bv2nCi5Qv5vroFiqKGopiw  ACFtxLv8pGrrxMm6EgjreA      4          9556
# 4    bv2nCi5Qv5vroFiqKGopiw  s2I_Ni76bjJNK9yG60iD-Q      4         47847
# 6    u0LXt3Uea_GidxRW1xcsfg  9_CGhHMz8698M9-PkVf0CQ      4          8999
# 8    u0LXt3Uea_GidxRW1xcsfg  5r6-G9C4YLbC7Ziz57l3rQ      3          5823
# 10   u0LXt3Uea_GidxRW1xcsfg  z8oIoCT1cXz7gZP5GeU5OA      4         53875
# 11   u0LXt3Uea_GidxRW1xcsfg  XWTPNfskXoUL-Lf32wSk0Q      3         29506
# 13   u0LXt3Uea_GidxRW1xcsfg  RtUvSWO_UZ8V3Wpj0n077w      3         24616
# 14   u0LXt3Uea_GidxRW1xcsfg  Aov96CM4FZAXeZvKtsStdA      5         10098
# 15   u0LXt3Uea_GidxRW1xcsfg  0W4lkclzZThpx3V65bVgig      4          1366
# 17   u0LXt3Uea_GidxRW1xcsfg  PFPUMF38-lraKzLcTiz5gQ      3         22386
# 18   u0LXt3Uea_GidxRW1xcsfg  oWTn2IzrprsRkPfULtjZtQ      3         44874
# 19   u0LXt3Uea_GidxRW1xcsfg  zgQHtqX0gqMw1nlBZl2VnQ      1         54354
# 20   u0LXt3Uea_GidxRW1xcsfg  28adZ4lsuUeVB2aWzohK9g      3          2711
# 22   u0LXt3Uea_GidxRW1xcsfg  Xy74meQwdTnloAAyRC-4cg      3         29894
# 123  nOTl4aPC4tKHK35T3bNauQ  xVEtGucSRLk5pxxN0t4i6g      5         52483
# 124  nOTl4aPC4tKHK35T3bNauQ  6Toez65egZSMV1iohQWGIQ      4          6324
# 127  nOTl4aPC4tKHK35T3bNauQ  iL2pb5Khi6jV113vOVQCvA      4         39589
# 128  nOTl4aPC4tKHK35T3bNauQ  bKh66jlEqEKZZFkjWipt8w      4         33646
# 129  nOTl4aPC4tKHK35T3bNauQ  lUstDPzw7aEmnHoR2L_SYw      2         42238
# 130  nOTl4aPC4tKHK35T3bNauQ  s9TzmT2kZmOZkTa53D2e3g      3         47936
# 131  nOTl4aPC4tKHK35T3bNauQ  HxLouUPqiou7D6YK5t-DgQ      3         16179
# 132  nOTl4aPC4tKHK35T3bNauQ  c78Pat78fVUBFPXYeVvbaQ      5         34292
# 133  nOTl4aPC4tKHK35T3bNauQ  GNEjlH_KssnJVRtqV4hAiw      4         14836
# 134  nOTl4aPC4tKHK35T3bNauQ  L6R2Op88NkoG1EGxlVvdRQ      4         18909
# 135  nOTl4aPC4tKHK35T3bNauQ  _vZ7bHaGCjllogiZ7RH17w      3         32397
# 139  nOTl4aPC4tKHK35T3bNauQ  vnIdWzIB2W4j9cDcd6tHAQ      3         51010
# 140  nOTl4aPC4tKHK35T3bNauQ  ILlebFUb89ZozizpVGeHdQ      3         16511
# 141  nOTl4aPC4tKHK35T3bNauQ  R3Cg6XvdBNXXNbEu6M977A      4         23943
# 143  nOTl4aPC4tKHK35T3bNauQ  SN0-O-CuIsyZf3LGZVEUAw      1         25048
# 145  nOTl4aPC4tKHK35T3bNauQ  pZ1quwXnYozLIZIVABojhw      4         45759
#
#      userID
# 0    567214
# 1    567214
# 2    567214
# 3    567214
# 4    567214
# 6    823880
# 8    823880
# 10   823880
# 11   823880
# 13   823880
# 14   823880
# 15   823880
# 17   823880
# 18   823880
# 19   823880
# 20   823880
# 22   823880
# 23   823880
# 24   823880
# 25   823880
# 26   823880
# 28   823880
# 30   823880
# 31   823880
# 32   823880
# 34   823880
# 37   823880
# 38   823880
# 39   823880
# 40   823880
# ..      ...
# 100  730374
# 101  730374
# 103  730374
# 106  730374
# 109  730374
# 110  730374
# 111  730374
# 112  730374
# 115  730374
# 117  730374
# 118  730374
# 119  730374
# 121  730374
# 122  730374
# 123  730374
# 124  730374
# 127  730374
# 128  730374
# 129  730374
# 130  730374
# 131  730374
# 132  730374
# 133  730374
# 134  730374
# 135  730374
# 139  730374
# 140  730374
# 141  730374
# 143  730374
# 145  730374
#
# [100 rows x 5 columns]

# %%
restRevDF.to_csv('../data/yelp_restaurant_review.csv', encoding='utf-8', index=False)

# %%
restRevSmallDF = restRevDF.head(10000)
restRevSmallDF.to_csv('../data/yelp_restaurant_review_small.csv', encoding='utf-8', index=False)
